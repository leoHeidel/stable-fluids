# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="-1"    
import tensorflow as tf

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import animation, rc
from IPython.display import HTML

from renderer import Renderer

# %%
print("GPUs found :", tf.config.experimental.list_physical_devices("GPU"))
# Out:
# GPUs found : []

# %%
# %%time
m,n,p = 100,101,102
sphere = np.zeros((p, m,n))
for i in range(m) :
    for j in range(n) :
        for k in range(p) :
            v = np.array([i,j,k])
            d = v - np.array([20,10,10])
            d2 = v - np.array([30,39,20])
            if np.sum(d*d) < 10 or np.sum(d2*d2) < 10 :
                sphere[k, i,j] = 1

sphere[1:5,1:5,1:5] = 1
# Out:
# CPU times: user 10.8 s, sys: 526 µs, total: 10.8 s
# Wall time: 10.8 s

# %%
renderer = Renderer(150,180, 150)

# %%
# %%time
ims = []
array = sphere
center = (np.array([p,m,n])-1)/2
fig = plt.figure()
t = 0

for i in range(100) :
    camera_pos = center +180*np.array([-np.cos(t),0,-np.sin(t)])
    plt.axis('off')
    res = renderer(sphere, camera_pos)
    ims.append([plt.imshow(res, animated=True)])
    t += 3.14150*2/100
# Out:
# CPU times: user 1min 2s, sys: 4.97 s, total: 1min 7s
# Wall time: 14.6 s

# %%
ani1 = animation.ArtistAnimation(fig, ims, interval=50, blit=True,
                                repeat_delay=1000)
HTML(ani1.to_html5_video())
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...
